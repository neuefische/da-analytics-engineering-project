# %%
import pandas as pd
from sqlalchemy import create_engine, types
from sqlalchemy import text # to be able to pass string

# %%
# Let's load values from the .env file
from dotenv import dotenv_values

config = dotenv_values()

# define variables for the login
pg_user = config['POSTGRES_USER']  # align the key label with your .env file !
pg_host = config['POSTGRES_HOST']
pg_port = config['POSTGRES_PORT']
pg_db = config['POSTGRES_DB']
pg_schema = config['POSTGRES_SCHEMA']
pg_pass = config['POSTGRES_PASS']

# %%
# Now building the URL with the values from the .env file

url = f'postgresql://{pg_user}:{pg_pass}@{pg_host}:{pg_port}/{pg_db}'

# without specifying the schema default connection is to the schema `public`
# url = f'postgresql://{pg_user}:{pg_pass}@{pg_host}:{pg_port}/{pg_db}'

# %%
engine = create_engine(url, echo=False)

# %%
my_schema = 'crush' # update it to your schema

with engine.begin() as conn: 
    result = conn.execute(text(f'SET search_path TO {my_schema};'))

# %%
df_flights = pd.read_sql("SELECT * FROM prep_flights;", con=engine)
df_weather = pd.read_sql("SELECT * FROM prep_weather;", con=engine)

# %%
# Out:
#      flight_date origin dest  dep_time  arr_time  sched_dep_time  \
# 0     2003-02-01    IAD  ATL     544.0     726.0             550
# 1     2003-02-01    IAD  DFW     607.0     833.0             610
# 2     2003-02-01    IAD  ORD     617.0     707.0             620
# 3     2003-02-01    IAD  CVG     621.0     758.0             625
# 4     2003-02-01    IAD  DTW       NaN       NaN             625
# ...          ...    ...  ...       ...       ...             ...
# 8232  2003-02-28    IAD  PHL    2127.0    2219.0            2135
# 8233  2003-02-28    IAD  SCE    2136.0    2224.0            2135
# 8234  2003-02-28    IAD  MCO    2131.0    2341.0            2135
# 8235  2003-02-28    IAD  TPA    2133.0    2342.0            2135
# 8236  2003-02-28    IAD  HPN    2255.0      13.0            2140
#
#       sched_arr_time  dep_delay  arr_delay  cancelled  diverted  \
# 0                732       -6.0       -6.0          0         0
# 1                829       -3.0        4.0          0         0
# 2                720       -3.0      -13.0          0         0
# 3                801       -4.0       -3.0          0         0
# 4                759        NaN        NaN          1         0
# ...              ...        ...        ...        ...       ...
# 8232            2231       -7.0      -12.0          0         0
# 8233            2225        1.0       -1.0          0         0
# 8234            2349       -4.0       -8.0          0         0
# 8235            2351       -2.0       -9.0          0         0
# 8236            2305       75.0       68.0          0         0
#
#       distance_miles  distance_km  air_time_minutes
# 0                533   857.780617              79.0
# 1               1172  1886.151752             164.0
# 2                589   947.903909              87.0
# 3                388   624.425665              73.0
# 4                383   616.378943               NaN
# ...              ...          ...               ...
# 8232             134   215.652163              35.0
# 8233             133   214.042818              31.0
# 8234             758  1219.883129             114.0
# 8235             810  1303.569043             117.0
# 8236             247   397.508091              62.0
#
# [8237 rows x 14 columns]

# %%
df_weather
# Out:
#      airport_code  station_id           timestamp  temp_c  dewpoint_c  \
# 0             BWI       72406 2003-02-07 00:00:00     0.0        -6.6
# 1             BWI       72406 2003-02-07 01:00:00    -1.7        -2.8
# 2             BWI       72406 2003-02-07 02:00:00    -1.7        -1.7
# 3             BWI       72406 2003-02-07 03:00:00    -1.7        -1.7
# 4             BWI       72406 2003-02-07 04:00:00    -1.7        -1.7
# ...           ...         ...                 ...     ...         ...
# 1915          LGA       72503 2003-02-26 19:00:00    -7.2       -14.9
# 1916          LGA       72503 2003-02-26 20:00:00    -6.1       -13.9
# 1917          LGA       72503 2003-02-26 21:00:00    -6.7       -12.8
# 1918          LGA       72503 2003-02-26 22:00:00    -6.1       -12.2
# 1919          LGA       72503 2003-02-26 23:00:00    -6.1       -12.8
#
#       humidity_perc  precipitation_mm snow_mm  wind_direction  wind_speed_kmh  \
# 0              61.0               0.0    None           130.0             9.4
# 1              92.0               NaN    None           170.0             7.6
# 2             100.0               1.0    None             0.0             0.0
# 3             100.0               1.5    None             0.0             0.0
# 4             100.0               1.5    None           110.0             5.4
# ...             ...               ...     ...             ...             ...
# 1915           54.0               0.0    None            50.0            18.7
# 1916           54.0               0.0    None            70.0            14.8
# 1917           62.0               0.0    None            50.0            14.8
# 1918           62.0               0.0    None            50.0            13.0
# 1919           59.0               0.0    None            60.0            11.2
#
#       ...        date      time   hour month_name    weekday date_day  \
# 0     ...  2003-02-07  00:00:00  00:00   february     friday      7.0
# 1     ...  2003-02-07  01:00:00  01:00   february     friday      7.0
# 2     ...  2003-02-07  02:00:00  02:00   february     friday      7.0
# 3     ...  2003-02-07  03:00:00  03:00   february     friday      7.0
# 4     ...  2003-02-07  04:00:00  04:00   february     friday      7.0
# ...   ...         ...       ...    ...        ...        ...      ...
# 1915  ...  2003-02-26  19:00:00  19:00   february  wednesday     26.0
# 1916  ...  2003-02-26  20:00:00  20:00   february  wednesday     26.0
# 1917  ...  2003-02-26  21:00:00  21:00   february  wednesday     26.0
# 1918  ...  2003-02-26  22:00:00  22:00   february  wednesday     26.0
# 1919  ...  2003-02-26  23:00:00  23:00   february  wednesday     26.0
#
#      date_month date_year   cw  day_part
# 0           2.0    2003.0  6.0     night
# 1           2.0    2003.0  6.0     night
# 2           2.0    2003.0  6.0     night
# 3           2.0    2003.0  6.0     night
# 4           2.0    2003.0  6.0     night
# ...         ...       ...  ...       ...
# 1915        2.0    2003.0  9.0   evening
# 1916        2.0    2003.0  9.0   evening
# 1917        2.0    2003.0  9.0   evening
# 1918        2.0    2003.0  9.0   evening
# 1919        2.0    2003.0  9.0   evening
#
# [1920 rows x 24 columns]
